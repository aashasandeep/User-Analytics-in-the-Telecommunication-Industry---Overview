# %% [markdown]
# <a href="https://colab.research.google.com/github/aashasandeep/User-Analytics-in-the-Telecommunication-Industry---Overview/blob/main/Telecom_data_Exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import liabraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading the data

# %%
Telecom_data = pd.read_excel('/content/telcom_data (1).xlsx')

# %%
Telecom_data.head(5)
# Out:
#               Bearer Id               Start  Start ms                 End  \
# 0  13114483460844900352 2019-04-04 12:01:18     770.0 2019-04-25 14:35:31
# 1  13114483482878900224 2019-04-09 13:04:04     235.0 2019-04-25 08:15:48
# 2  13114483484080500736 2019-04-09 17:42:11       1.0 2019-04-25 11:58:13
# 3  13114483485442799616 2019-04-10 00:31:25     486.0 2019-04-25 07:36:35
# 4  13114483499480700928 2019-04-12 20:10:23     565.0 2019-04-25 10:40:32
#
#    End ms  Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0   662.0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1   606.0  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2   652.0  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3   171.0  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4   954.0  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#   Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# ...

# %%
Telecom_data.columns
# Out:
# Index(['Bearer Id', 'Start', 'Start ms', 'End', 'End ms', 'Dur. (ms)', 'IMSI',
#        'MSISDN/Number', 'IMEI', 'Last Location Name', 'Avg RTT DL (ms)',
#        'Avg RTT UL (ms)', 'Avg Bearer TP DL (kbps)', 'Avg Bearer TP UL (kbps)',
#        'TCP DL Retrans. Vol (Bytes)', 'TCP UL Retrans. Vol (Bytes)',
#        'DL TP < 50 Kbps (%)', '50 Kbps < DL TP < 250 Kbps (%)',
#        '250 Kbps < DL TP < 1 Mbps (%)', 'DL TP > 1 Mbps (%)',
#        'UL TP < 10 Kbps (%)', '10 Kbps < UL TP < 50 Kbps (%)',
#        '50 Kbps < UL TP < 300 Kbps (%)', 'UL TP > 300 Kbps (%)',
#        'HTTP DL (Bytes)', 'HTTP UL (Bytes)', 'Activity Duration DL (ms)',
#        'Activity Duration UL (ms)', 'Dur. (ms).1', 'Handset Manufacturer',
#        'Handset Type', 'Nb of sec with 125000B < Vol DL',
#        'Nb of sec with 1250B < Vol UL < 6250B',
#        'Nb of sec with 31250B < Vol DL < 125000B',
#        'Nb of sec with 37500B < Vol UL',
#        'Nb of sec with 6250B < Vol DL < 31250B',
# ...

# %% [markdown]
#  Information about the data

# %%
Telecom_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 55 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   Bearer Id                                 150001 non-null  object
#  1   Start                                     150000 non-null  datetime64[ns]
#  2   Start ms                                  150000 non-null  float64
#  3   End                                       150000 non-null  datetime64[ns]
#  4   End ms                                    150000 non-null  float64
#  5   Dur. (ms)                                 150000 non-null  float64
#  6   IMSI                                      149431 non-null  float64
#  7   MSISDN/Number                             148935 non-null  float64
#  8   IMEI                                      149429 non-null  float64
# ...

# %%
Telecom_data.shape# shape of the data
# Out:
# (150001, 55)

# %%
Telecom_data.shape[0]#Rows of the data
# Out:
# 150001

# %%
Telecom_data.shape[1]#columns of the data
# Out:
# 55

# %% [markdown]
# Checked the duplicated entries

# %%
Telecom_data.duplicated().sum()
# Out:
# 0

# %%
Telecom_data.describe()
# Out:
#                                Start       Start ms  \
# count                         150000  150000.000000
# mean   2019-04-26 12:36:38.953740032     499.188200
# min              2019-04-04 12:01:18       0.000000
# 25%    2019-04-25 00:26:00.750000128     250.000000
# 50%       2019-04-26 08:51:24.500000     499.000000
# 75%    2019-04-27 18:18:59.750000128     749.000000
# max              2019-04-29 07:28:43     999.000000
# std                              NaN     288.611834
#
#                                  End         End ms     Dur. (ms)  \
# count                         150000  150000.000000  1.500000e+05
# mean   2019-04-27 17:40:08.059673344     498.800880  1.046086e+05
# min              2019-04-24 22:59:58       0.000000  7.142000e+03
# 25%       2019-04-26 07:30:11.500000     251.000000  5.744050e+04
# 50%              2019-04-27 23:02:05     500.000000  8.639900e+04
# 75%       2019-04-29 07:15:07.500000     750.000000  1.324302e+05
# ...

# %%
Telecom_data.describe().T
# Out:
#                                              count  \
# Start                                       150000
# Start ms                                  150000.0
# End                                         150000
# End ms                                    150000.0
# Dur. (ms)                                 150000.0
# IMSI                                      149431.0
# MSISDN/Number                             148935.0
# IMEI                                      149429.0
# Avg RTT DL (ms)                           122172.0
# Avg RTT UL (ms)                           122189.0
# Avg Bearer TP DL (kbps)                   150000.0
# Avg Bearer TP UL (kbps)                   150000.0
# TCP DL Retrans. Vol (Bytes)                61855.0
# TCP UL Retrans. Vol (Bytes)                53352.0
# DL TP < 50 Kbps (%)                       149247.0
# 50 Kbps < DL TP < 250 Kbps (%)            149247.0
# 250 Kbps < DL TP < 1 Mbps (%)             149247.0
# ...

# %% [markdown]
# Checked missing values

# %%
missing_values = Telecom_data.isnull().sum()
missing_values[missing_values > 0]
# Out:
# Start                                            1
# Start ms                                         1
# End                                              1
# End ms                                           1
# Dur. (ms)                                        1
# IMSI                                           570
# MSISDN/Number                                 1066
# IMEI                                           572
# Last Location Name                            1153
# Avg RTT DL (ms)                              27829
# Avg RTT UL (ms)                              27812
# Avg Bearer TP DL (kbps)                          1
# Avg Bearer TP UL (kbps)                          1
# TCP DL Retrans. Vol (Bytes)                  88146
# TCP UL Retrans. Vol (Bytes)                  96649
# DL TP < 50 Kbps (%)                            754
# 50 Kbps < DL TP < 250 Kbps (%)                 754
# 250 Kbps < DL TP < 1 Mbps (%)                  754
# ...

# %%
Telecom_data.isnull().sum()
# Out:
# Bearer Id                                        0
# Start                                            1
# Start ms                                         1
# End                                              1
# End ms                                           1
# Dur. (ms)                                        1
# IMSI                                           570
# MSISDN/Number                                 1066
# IMEI                                           572
# Last Location Name                            1153
# Avg RTT DL (ms)                              27829
# Avg RTT UL (ms)                              27812
# Avg Bearer TP DL (kbps)                          1
# Avg Bearer TP UL (kbps)                          1
# TCP DL Retrans. Vol (Bytes)                  88146
# TCP UL Retrans. Vol (Bytes)                  96649
# DL TP < 50 Kbps (%)                            754
# 50 Kbps < DL TP < 250 Kbps (%)                 754
# ...

# %%
#  Filling numerical missing values with median
numerical_cols = Telecom_data.select_dtypes(include=['float64', 'int64']).columns
Telecom_data[numerical_cols] = Telecom_data[numerical_cols].apply(lambda x: x.fillna(x.median()), axis=0)

# %%
# Filling categorical missing values with 'Unknown'
categorical_cols = Telecom_data.select_dtypes(include=['object']).columns
Telecom_data[categorical_cols] = Telecom_data[categorical_cols].apply(lambda x: x.fillna('Unknown'))

# %%
Telecom_data['Start'] = Telecom_data['Start'].fillna('2019-04-29 07:08:38')

# %%
Telecom_data['End'] = Telecom_data['End'].fillna('2019-04-25 00:01:32')

# %%
Telecom_data.isnull().sum().iloc[0:55]
# Out:
# Bearer Id                                   0
# Start                                       0
# Start ms                                    0
# End                                         0
# End ms                                      0
# Dur. (ms)                                   0
# IMSI                                        0
# MSISDN/Number                               0
# IMEI                                        0
# Last Location Name                          0
# Avg RTT DL (ms)                             0
# Avg RTT UL (ms)                             0
# Avg Bearer TP DL (kbps)                     0
# Avg Bearer TP UL (kbps)                     0
# TCP DL Retrans. Vol (Bytes)                 0
# TCP UL Retrans. Vol (Bytes)                 0
# DL TP < 50 Kbps (%)                         0
# 50 Kbps < DL TP < 250 Kbps (%)              0
# 250 Kbps < DL TP < 1 Mbps (%)               0
# DL TP > 1 Mbps (%)                          0
# ...

# %%
Telecom_data.dtypes
# Out:
# Bearer Id                                           object
# Start                                       datetime64[ns]
# Start ms                                           float64
# End                                         datetime64[ns]
# End ms                                             float64
# Dur. (ms)                                          float64
# IMSI                                               float64
# MSISDN/Number                                      float64
# IMEI                                               float64
# Last Location Name                                  object
# Avg RTT DL (ms)                                    float64
# Avg RTT UL (ms)                                    float64
# Avg Bearer TP DL (kbps)                            float64
# Avg Bearer TP UL (kbps)                            float64
# TCP DL Retrans. Vol (Bytes)                        float64
# TCP UL Retrans. Vol (Bytes)                        float64
# ...

# %% [markdown]
# Outliers by quantile method

# %%
Q1 = Telecom_data[numerical_cols].quantile(0.25)
Q3 = Telecom_data[numerical_cols].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

outliers = Telecom_data[(Telecom_data[numerical_cols] < lower_bound) | (Telecom_data[numerical_cols] > upper_bound)]

# %% [markdown]
# Boxplot for Outliers

# %%
plt.figure(figsize=(12,3),dpi=200)
outliers.plot(kind = 'box',color = 'Green')
plt.xticks(rotation = 90)
plt.title('total outliers', color = 'Green')
plt.ylabel('values',color = 'Green')
plt.show()

# %%
Telecom_data.to_excel('/content/Cleaned_telcom_data (1).xlsx',index=False)
